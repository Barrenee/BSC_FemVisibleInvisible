# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import HeatMap
import rasterio
from rasterio.plot import show
import xarray as xr
import numpy as np
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D

# %%
# 1. Load GeoJSON data (road_transport_interurban_CAT)
roads = gpd.read_file('../road_transport_interurban_CAT.geojson')

# %%
# 2. Load shapefiles (population grid and administrative divisions)
population = gpd.read_file('../Poblacio/gridpoblacio01012022.shp')

# %%
# 3. Load road links shapefiles
road_links = gpd.read_file('../OpenTransportMap/Barcelona/roadlinks_ES511.shp')

# %%
administrative_divisions = gpd.read_file('../LimitsAdministratius/Comarques/divisions-administratives-v2r1-comarques-5000-20240705.shp')

# %%
# !python -m pip install "xarray[complete]"
# Out:
# Requirement already satisfied: xarray[complete] in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2024.11.0)
# Requirement already satisfied: numpy>=1.24 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from xarray[complete]) (1.26.3)
# Requirement already satisfied: packaging>=23.2 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from xarray[complete]) (23.2)
# Requirement already satisfied: pandas>=2.1 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from xarray[complete]) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=2.1->xarray[complete]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=2.1->xarray[complete]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=2.1->xarray[complete]) (2024.1)
# Requirement already satisfied: scipy in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from xarray[complete]) (1.12.0)
# Collecting bottleneck (from xarray[complete])
#   Downloading Bottleneck-1.4.2-cp311-cp311-win_amd64.whl.metadata (7.9 kB)
# Collecting numbagg (from xarray[complete])
#   Downloading numbagg-0.8.2-py3-none-any.whl.metadata (47 kB)
# Requirement already satisfied: numba>=0.54 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from xarray[complete]) (0.59.0)
# Collecting flox (from xarray[complete])
#   Downloading flox-0.9.15-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: opt_einsum in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from xarray[complete]) (3.3.0)
# Requirement already satisfied: netCDF4 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from xarray[complete]) (1.7.2)
# Requirement already satisfied: h5netcdf in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from xarray[complete]) (1.4.1)
# Requirement already satisfied: zarr in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from xarray[complete]) (2.18.4)
# Requirement already satisfied: fsspec in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from xarray[complete]) (2024.5.0)
# Requirement already satisfied: cftime in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from xarray[complete]) (1.6.4.post1)
# Requirement already satisfied: pooch in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from xarray[complete]) (1.8.1)
# Collecting sparse (from xarray[complete])
#   Downloading sparse-0.15.4-py2.py3-none-any.whl.metadata (4.5 kB)
# Collecting dask[complete] (from xarray[complete])
#   Downloading dask-2024.12.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting cartopy (from xarray[complete])
#   Downloading Cartopy-0.24.1-cp311-cp311-win_amd64.whl.metadata (8.1 kB)
# Requirement already satisfied: matplotlib in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from xarray[complete]) (3.8.2)
# Collecting nc-time-axis (from xarray[complete])
#   Downloading nc_time_axis-1.4.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: seaborn in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from xarray[complete]) (0.13.2)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from numba>=0.54->xarray[complete]) (0.42.0)
# Requirement already satisfied: six>=1.5 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas>=2.1->xarray[complete]) (1.16.0)
# Requirement already satisfied: shapely>=1.8 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cartopy->xarray[complete]) (2.0.4)
# Collecting pyshp>=2.3 (from cartopy->xarray[complete])
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl.metadata (55 kB)
# Requirement already satisfied: pyproj>=3.3.1 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cartopy->xarray[complete]) (3.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->xarray[complete]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->xarray[complete]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->xarray[complete]) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->xarray[complete]) (1.4.5)
# Requirement already satisfied: pillow>=8 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->xarray[complete]) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib->xarray[complete]) (3.1.1)
# Requirement already satisfied: click>=8.1 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dask[complete]; extra == "parallel"->xarray[complete]) (8.1.7)
# Requirement already satisfied: cloudpickle>=3.0.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dask[complete]; extra == "parallel"->xarray[complete]) (3.0.0)
# Collecting partd>=1.4.0 (from dask[complete]; extra == "parallel"->xarray[complete])
#   Downloading partd-1.4.2-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dask[complete]; extra == "parallel"->xarray[complete]) (6.0.1)
# Collecting toolz>=0.10.0 (from dask[complete]; extra == "parallel"->xarray[complete])
#   Downloading toolz-1.0.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: importlib_metadata>=4.13.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dask[complete]; extra == "parallel"->xarray[complete]) (7.0.2)
# Requirement already satisfied: pyarrow>=14.0.1 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dask[complete]; extra == "parallel"->xarray[complete]) (16.1.0)
# Requirement already satisfied: lz4>=4.3.2 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dask[complete]; extra == "parallel"->xarray[complete]) (4.3.3)
# Collecting numpy-groupies>=0.9.19 (from flox->xarray[complete])
#   Downloading numpy_groupies-0.11.2-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: h5py in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from h5netcdf->xarray[complete]) (3.11.0)
# Requirement already satisfied: certifi in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from netCDF4->xarray[complete]) (2024.2.2)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pooch->xarray[complete]) (4.2.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pooch->xarray[complete]) (2.32.3)
# Requirement already satisfied: asciitree in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from zarr->xarray[complete]) (0.3.3)
# Requirement already satisfied: fasteners in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from zarr->xarray[complete]) (0.19)
# Requirement already satisfied: numcodecs!=0.14.0,!=0.14.1,>=0.10.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from zarr->xarray[complete]) (0.13.1)
# Requirement already satisfied: colorama in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from click>=8.1->dask[complete]; extra == "parallel"->xarray[complete]) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from importlib_metadata>=4.13.0->dask[complete]; extra == "parallel"->xarray[complete]) (3.18.1)
# Collecting locket (from partd>=1.4.0->dask[complete]; extra == "parallel"->xarray[complete])
#   Downloading locket-1.0.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.19.0->pooch->xarray[complete]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.19.0->pooch->xarray[complete]) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests>=2.19.0->pooch->xarray[complete]) (2.2.0)
# Collecting dask-expr<1.2,>=1.1 (from dask[complete]->xarray[complete])
#   Downloading dask_expr-1.1.20-py3-none-any.whl.metadata (2.6 kB)
# Collecting distributed==2024.12.0 (from dask[complete]->xarray[complete])
#   Downloading distributed-2024.12.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting bokeh>=3.1.0 (from dask[complete]->xarray[complete])
#   Downloading bokeh-3.6.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: jinja2>=2.10.3 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dask[complete]->xarray[complete]) (3.1.3)
# Requirement already satisfied: msgpack>=1.0.2 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from distributed==2024.12.0->dask[complete]->xarray[complete]) (1.0.7)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from distributed==2024.12.0->dask[complete]->xarray[complete]) (5.9.8)
# Requirement already satisfied: sortedcontainers>=2.0.5 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from distributed==2024.12.0->dask[complete]->xarray[complete]) (2.4.0)
# Collecting tblib>=1.6.0 (from distributed==2024.12.0->dask[complete]->xarray[complete])
#   Downloading tblib-3.0.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from distributed==2024.12.0->dask[complete]->xarray[complete]) (6.4)
# Collecting zict>=3.0.0 (from distributed==2024.12.0->dask[complete]->xarray[complete])
#   Downloading zict-3.0.0-py2.py3-none-any.whl.metadata (899 bytes)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from bokeh>=3.1.0->dask[complete]->xarray[complete]) (2024.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\usuario\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jinja2>=2.10.3->dask[complete]->xarray[complete]) (2.1.5)
# Downloading Bottleneck-1.4.2-cp311-cp311-win_amd64.whl (111 kB)
# Downloading Cartopy-0.24.1-cp311-cp311-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 882.6 kB/s eta 0:00:12
#    -- ------------------------------------- 0.8/11.0 MB 985.5 kB/s eta 0:00:11
#    --- ------------------------------------ 1.0/11.0 MB 931.8 kB/s eta 0:00:11
#    ---- ----------------------------------- 1.3/11.0 MB 986.4 kB/s eta 0:00:10
#    ----- ---------------------------------- 1.6/11.0 MB 1.0 MB/s eta 0:00:10
#    ------ --------------------------------- 1.8/11.0 MB 1.0 MB/s eta 0:00:09
#    ------- -------------------------------- 2.1/11.0 MB 1.1 MB/s eta 0:00:09
#    -------- ------------------------------- 2.4/11.0 MB 1.1 MB/s eta 0:00:08
#    -------- ------------------------------- 2.4/11.0 MB 1.1 MB/s eta 0:00:08
#    --------- ------------------------------ 2.6/11.0 MB 1.0 MB/s eta 0:00:09
#    ---------- ----------------------------- 2.9/11.0 MB 1.0 MB/s eta 0:00:08
#    ----------- ---------------------------- 3.1/11.0 MB 1.0 MB/s eta 0:00:08
#    ------------ --------------------------- 3.4/11.0 MB 1.0 MB/s eta 0:00:08
#    ------------ --------------------------- 3.4/11.0 MB 1.0 MB/s eta 0:00:08
#    ------------- -------------------------- 3.7/11.0 MB 1.0 MB/s eta 0:00:08
#    --------------- ------------------------ 4.2/11.0 MB 1.1 MB/s eta 0:00:07
#    ---------------- ----------------------- 4.5/11.0 MB 1.1 MB/s eta 0:00:07
#    ----------------- ---------------------- 4.7/11.0 MB 1.1 MB/s eta 0:00:06
#    ------------------ --------------------- 5.0/11.0 MB 1.1 MB/s eta 0:00:06
#    ------------------ --------------------- 5.0/11.0 MB 1.1 MB/s eta 0:00:06
#    ------------------- -------------------- 5.2/11.0 MB 1.1 MB/s eta 0:00:06
#    -------------------- ------------------- 5.5/11.0 MB 1.1 MB/s eta 0:00:06
#    --------------------- ------------------ 5.8/11.0 MB 1.1 MB/s eta 0:00:05
#    ---------------------- ----------------- 6.0/11.0 MB 1.1 MB/s eta 0:00:05
#    ---------------------- ----------------- 6.0/11.0 MB 1.1 MB/s eta 0:00:05
#    ----------------------- ---------------- 6.6/11.0 MB 1.1 MB/s eta 0:00:05
#    ------------------------ --------------- 6.8/11.0 MB 1.1 MB/s eta 0:00:04
#    ------------------------- -------------- 7.1/11.0 MB 1.1 MB/s eta 0:00:04
#    -------------------------- ------------- 7.3/11.0 MB 1.1 MB/s eta 0:00:04
#    --------------------------- ------------ 7.6/11.0 MB 1.1 MB/s eta 0:00:04
#    ---------------------------- ----------- 7.9/11.0 MB 1.1 MB/s eta 0:00:03
#    ----------------------------- ---------- 8.1/11.0 MB 1.1 MB/s eta 0:00:03
#    ------------------------------- -------- 8.7/11.0 MB 1.2 MB/s eta 0:00:02
#    -------------------------------- ------- 8.9/11.0 MB 1.2 MB/s eta 0:00:02
#    --------------------------------- ------ 9.2/11.0 MB 1.2 MB/s eta 0:00:02
#    ----------------------------------- ---- 9.7/11.0 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------ --- 10.0/11.0 MB 1.2 MB/s eta 0:00:01
#    -------------------------------------- - 10.5/11.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 1.2 MB/s eta 0:00:00
# Downloading flox-0.9.15-py3-none-any.whl (70 kB)
# Downloading nc_time_axis-1.4.1-py3-none-any.whl (17 kB)
# Downloading numbagg-0.8.2-py3-none-any.whl (49 kB)
# Downloading sparse-0.15.4-py2.py3-none-any.whl (237 kB)
# Downloading numpy_groupies-0.11.2-py3-none-any.whl (40 kB)
# Downloading partd-1.4.2-py3-none-any.whl (18 kB)
# Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
# Downloading toolz-1.0.0-py3-none-any.whl (56 kB)
# Downloading dask-2024.12.0-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.3 MB ? eta -:--:--
#    ---------------- ----------------------- 0.5/1.3 MB 1.5 MB/s eta 0:00:01
#    ------------------------ --------------- 0.8/1.3 MB 1.4 MB/s eta 0:00:01
#    --------------------------------- ------ 1.0/1.3 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 1.5 MB/s eta 0:00:00
# Downloading distributed-2024.12.0-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    -------------------- ------------------- 0.5/1.0 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 1.7 MB/s eta 0:00:00
# Downloading bokeh-3.6.2-py3-none-any.whl (6.9 MB)
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.9 MB 1.5 MB/s eta 0:00:05
#    ---- ----------------------------------- 0.8/6.9 MB 1.6 MB/s eta 0:00:04
#    ------- -------------------------------- 1.3/6.9 MB 1.7 MB/s eta 0:00:04
#    --------- ------------------------------ 1.6/6.9 MB 1.7 MB/s eta 0:00:04
#    ------------ --------------------------- 2.1/6.9 MB 1.8 MB/s eta 0:00:03
#    ------------- -------------------------- 2.4/6.9 MB 1.7 MB/s eta 0:00:03
#    ---------------- ----------------------- 2.9/6.9 MB 1.8 MB/s eta 0:00:03
#    ------------------ --------------------- 3.1/6.9 MB 1.8 MB/s eta 0:00:03
#    --------------------- ------------------ 3.7/6.9 MB 1.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 3.9/6.9 MB 1.8 MB/s eta 0:00:02
#    ------------------------- -------------- 4.5/6.9 MB 1.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 5.0/6.9 MB 1.9 MB/s eta 0:00:02
#    ------------------------------ --------- 5.2/6.9 MB 1.8 MB/s eta 0:00:01
#    -------------------------------- ------- 5.5/6.9 MB 1.8 MB/s eta 0:00:01
#    --------------------------------- ------ 5.8/6.9 MB 1.8 MB/s eta 0:00:01
#    ------------------------------------ --- 6.3/6.9 MB 1.8 MB/s eta 0:00:01
#    -------------------------------------- - 6.6/6.9 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------  6.8/6.9 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 1.7 MB/s eta 0:00:00
# Downloading dask_expr-1.1.20-py3-none-any.whl (245 kB)
# Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Downloading tblib-3.0.0-py3-none-any.whl (12 kB)
# Downloading zict-3.0.0-py2.py3-none-any.whl (43 kB)
# Installing collected packages: zict, toolz, tblib, pyshp, numpy-groupies, locket, bottleneck, sparse, partd, numbagg, nc-time-axis, flox, dask, cartopy, bokeh, distributed, dask-expr
# Successfully installed bokeh-3.6.2 bottleneck-1.4.2 cartopy-0.24.1 dask-2024.12.0 dask-expr-1.1.20 distributed-2024.12.0 flox-0.9.15 locket-1.0.0 nc-time-axis-1.4.1 numbagg-0.8.2 numpy-groupies-0.11.2 partd-1.4.2 pyshp-2.3.1 sparse-0.15.4 tblib-3.0.0 toolz-1.0.0 zict-3.0.0

# %%
import xarray as xr
print(xr.backends.list_engines())
# Out:
# {'scipy': <ScipyBackendEntrypoint>
#   Open netCDF files (.nc, .nc4, .cdf and .gz) using scipy in Xarray
#   Learn more at https://docs.xarray.dev/en/stable/generated/xarray.backends.ScipyBackendEntrypoint.html, 'store': <StoreBackendEntrypoint>
#   Open AbstractDataStore instances in Xarray
#   Learn more at https://docs.xarray.dev/en/stable/generated/xarray.backends.StoreBackendEntrypoint.html}

# %%
# 4. Load NO2 data (NetCDF format)
no2_data = xr.open_dataset('../hourly/sconcno2/sconcno2_2021012700.nc', engine='netcdf4')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 2
#       1 # 4. Load NO2 data (NetCDF format)
# ----> 2 no2_data = xr.open_dataset('../hourly/sconcno2/sconcno2_2021012700.nc', engine='netcdf4')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\xarray\backends\api.py:656, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     653 if from_array_kwargs is None:
#     654     from_array_kwargs = {}
# --> 656 backend = plugins.get_backend(engine)
#     658 decoders = _resolve_decoders_kwargs(
#     659     decode_cf,
#     660     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     666     decode_coords=decode_coords,
#     667 )
#     669 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\xarray\backends\plugins.py:202, in get_backend(engine)
#     200     engines = list_engines()
#     201     if engine not in engines:
# --> 202         raise ValueError(
#     203             f"unrecognized engine '{engine}' must be one of your download engines: {list(engines)}. "
#     204             "To install additional dependencies, see:\n"
#     205             "https://docs.xarray.dev/en/stable/user-guide/io.html \n"
#     206             "https://docs.xarray.dev/en/stable/getting-started-guide/installing.html"
#     207         )
#     208     backend = engines[engine]
#     209 elif issubclass(engine, BackendEntrypoint):
#
# ValueError: unrecognized engine 'netcdf4' must be one of your download engines: ['scipy', 'store']. To install additional dependencies, see:
# https://docs.xarray.dev/en/stable/user-guide/io.html
# https://docs.xarray.dev/en/stable/getting-started-guide/installing.html

# %%
# Define a base map for visualization
catalonia_map = folium.Map(location=[41.8245, 1.5920], zoom_start=8)
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona\\ogrext.pyx:136, in fiona.ogrext.gdal_open_vector()
#
# File fiona\\_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: ../OpenTransportMap/Girona/divisions-administratives-v2r1-comarques-5000-20240705.cpg: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# Cell In[5], line 6
#       4 # 2. Load shapefiles (population grid and administrative divisions)
#       5 population = gpd.read_file('../Poblacio/gridpoblacio01012022.shp')
# ----> 6 administrative_divisions = gpd.read_file('../OpenTransportMap/Girona/divisions-administratives-v2r1-comarques-5000-20240705.cpg')
#       8 # 3. Load road links shapefiles
#       9 road_links = gpd.read_file('roadlinks_ES511.cpg')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\io\file.py:289, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     286     else:
#     287         path_or_bytes = filename
# --> 289     return _read_file_fiona(
#     290         path_or_bytes, from_bytes, bbox=bbox, mask=mask, rows=rows, **kwargs
#     291     )
#     293 else:
#     294     raise ValueError(f"unknown engine '{engine}'")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\geopandas\io\file.py:315, in _read_file_fiona(path_or_bytes, from_bytes, bbox, mask, rows, where, **kwargs)
#     312     reader = fiona.open
#     314 with fiona_env():
# --> 315     with reader(path_or_bytes, **kwargs) as features:
#     316         crs = features.crs_wkt
#     317         # attempt to get EPSG code
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fiona\env.py:457, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     454     session = DummySession()
#     456 with env_ctor(session=session):
# --> 457     return f(*args, **kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fiona\__init__.py:305, in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, allow_unsupported_drivers, **kwargs)
#     302     path = parse_path(fp)
#     304 if mode in ("a", "r"):
# --> 305     colxn = Collection(
#     306         path,
#     307         mode,
#     308         driver=driver,
#     309         encoding=encoding,
#     310         layer=layer,
#     311         enabled_drivers=enabled_drivers,
#     312         allow_unsupported_drivers=allow_unsupported_drivers,
#     313         **kwargs
#     314     )
#     315 elif mode == "w":
#     316     colxn = Collection(
#     317         path,
#     318         mode,
#    (...)
#     327         **kwargs
#     328     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\fiona\collection.py:243, in Collection.__init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, include_fields, wkt_version, allow_unsupported_drivers, **kwargs)
#     241 if self.mode == "r":
#     242     self.session = Session()
# --> 243     self.session.start(self, **kwargs)
#     244 elif self.mode in ("a", "w"):
#     245     self.session = WritingSession()
#
# File fiona\\ogrext.pyx:588, in fiona.ogrext.Session.start()
#
# File fiona\\ogrext.pyx:143, in fiona.ogrext.gdal_open_vector()
#
# DriverError: ../OpenTransportMap/Girona/divisions-administratives-v2r1-comarques-5000-20240705.cpg: No such file or directory

# %%
# Add roads to the map
for _, row in roads.iterrows():
    coords = [(lat, lon) for lon, lat, _ in row.geometry[0]]
    folium.PolyLine(coords, color='blue', weight=2.5, opacity=0.7).add_to(catalonia_map)

# Add population data
folium.Choropleth(
    geo_data=population,
    data=population,
    columns=['GRID_ID', 'POPULATION'],
    key_on='feature.properties.GRID_ID',
    fill_color='YlOrRd',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Population Density'
).add_to(catalonia_map)

# Add administrative boundaries
for _, row in administrative_divisions.iterrows():
    folium.Polygon(
        locations=[(lat, lon) for lon, lat in row.geometry.exterior.coords],
        color='green',
        weight=1,
        fill=True,
        fill_opacity=0.3
    ).add_to(catalonia_map)

# Extract NO2 grid and add heatmap
no2_array = no2_data['no2'].isel(time=0).values
lat = no2_data['lat'].values
lon = no2_data['lon'].values
no2_points = [(lat[i], lon[j], no2_array[i, j]) for i in range(len(lat)) for j in range(len(lon))]

HeatMap(
    data=[(p[0], p[1], p[2]) for p in no2_points],
    max_zoom=16,
    radius=15
).add_to(catalonia_map)



# Show Folium map
catalonia_map.save('catalonia_map.html')

# Save static map using Matplotlib
fig, ax = plt.subplots(figsize=(10, 10))
administrative_divisions.plot(ax=ax, color='none', edgecolor='black', linewidth=0.5)
roads.plot(ax=ax, color='blue', linewidth=0.5)
population.plot(ax=ax, column='POPULATION', cmap='YlOrRd', legend=True)
plt.title('Catalonia NO2 and Population Map')
plt.show()
